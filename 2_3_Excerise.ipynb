# %% [markdown]
# <a href="https://colab.research.google.com/github/KYM-35/YSHello/blob/main/2_3_Excerise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.DataFrame({'col1': [1,2,3], 'col2': [4,5,6]})
print(df)
# Out:
#    col1  col2
# 0     1     4
# 1     2     5
# 2     3     6
